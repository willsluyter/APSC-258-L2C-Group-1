# %% [markdown]
# # Lab Part 4
# # Neural Network Model Template
#
# This file contains boilerplate for creating a neural network. Designing a neural network is quite difficult and requires a lot of time to set up data processing pipelines and image processing. As well as making sure that the tensors and datasets are in the correct formats. This file contains all that you need to make your very own neural network.

# %%
# Config Parameters for the model
# Set the batch size here
# increase for systems with more memory, 32 should be enough for most systems
BATCH_SIZE = 32

# %% [markdown]
# ## Part 1: Unpack our data
# All we do is install 7zip and then use pyunpack to extract the files. This saves datasets to /notebooks which is a directory on Paperspace Gradient that is acceptable by python.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)

import zipfile

# dataset file name
data_file = "data_30" # change this to your dataset file name

zip_ref = zipfile.ZipFile("/content/gdrive/MyDrive/APSC_258_FUN_AND_GAMES/data_30.zip", 'r')
zip_ref.extractall()
zip_ref.close()

data_dir = '/content/' + data_file + '/'
train_dir = data_dir + 'train/' # directory for training images
test_dir = data_dir + 'test/' # directory for test images we use the test images to make sure our model is working well
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Part 3: Loading in the data
# ### Dealing with images
# Our image files that we are using for training are pretty large. Your computer may crash if we loaded them all at once so instead we will just store where the images are stored. Later you will see how we can automatically load these files when we run our code. One thing to note is that each image file is named (somenumber).jpg that number is the number of milliseconds since 1 January 1970 (Unix Time) when the file was recorded. This means that we will never have any overlapping files. Unfortunately this does mean we will have to sort the times from smallest to largest to make sure that they correspond with the steering angles which are recorded sequentially.
#
# ### Dealing with steering angles
# We store our steering values as a csv (comma separated values) file. Python has a built in csv module so we can easily use it to load in all the steering values into a list. These don't take up much ram so it doesn't matter if we load them all in at once. They're just numbers after all.
#
# ### Making sure the files line up
# Since we sort our images, and the csv file is read in line by line the files will line up with their correct steering angles. It looks something like this. If we mess this up then the data being fed into your network would be totally incoherent. Garbage in Garbage out.
#
# train_img =   | image 1    | image 2    | image 3    | image 4    | image 5    |...
#
# train_steer = | steering 1 | steering 2 | steering 3 | steering 4 | steering 5 |...

# %%
import csv
import os
# lets make a function that loads the images and labels
def load_data(directory):
    image__paths = []
    for file in os.listdir(directory): # for each file in the directory
        if file.endswith(".png"): # if the file is an image
            image__paths.append(directory + file) # add the image path to the list
    print(image__paths)
    # now our files are in the train list we need to sort them from smallest file name to largest. The file name is the exact time the image was taken.
    image__paths.sort(key=lambda x: int(x.split('/')[-1][:-4].split('_')[0][:])) # the lambda function returns the numbers in the file name
    print(image__paths)
    # now we get the steering angles
    steering_angles = [] # create a list to store the steering angles
    for angle in image__paths: # for each row in the csv file
        steering_angles.append(float(angle.split('/')[-1][:-4].split('_')[-1].replace('-','.'))) # add the steering angle to the list
    print(steering_angles)
    return image__paths, steering_angles # return the image paths and steering angles

# We call our load data function to get the image paths and steering angles
train_img, train_steer = load_data(train_dir) # load the training data
test_img, test_steer = load_data(test_dir) # load the test data
# Out:
# ['/content/data_30/train/3225_165.png', '/content/data_30/train/3455_102-773.png', '/content/data_30/train/2226_111-33.png', '/content/data_30/train/183_121-588.png', '/content/data_30/train/658_68-76.png', '/content/data_30/train/2566_111-613.png', '/content/data_30/train/1135_69-691.png', '/content/data_30/train/1572_60-871.png', '/content/data_30/train/4616_81-765.png', '/content/data_30/train/4230_52-687.png', '/content/data_30/train/2188_115-089.png', '/content/data_30/train/4167_38-853.png', '/content/data_30/train/1755_60-989.png', '/content/data_30/train/3556_95-485.png', '/content/data_30/train/3770_69-714.png', '/content/data_30/train/4311_67-556.png', '/content/data_30/train/1942_95-096.png', '/content/data_30/train/2781_108-861.png', '/content/data_30/train/3516_98-803.png', '/content/data_30/train/144_124-106.png', '/content/data_30/train/4345_71-825.png', '/content/data_30/train/4680_81-812.png', '/content/data_30/train/4648_81-377.png', '/content/data_30/train/2970_98-41.png', '/content/data_30/train/1826_77-58.png', '/content/data_30/train/3016_97-192.png', '/content/data_30/train/2620_115-563.png', '/content/data_30/train/3785_68-238.png', '/content/data_30/train/3391_118-567.png', '/content/data_30/train/1885_87-986.png', '/content/data_30/train/449_99-489.png', '/content/data_30/train/3266_165.png', '/content/data_30/train/4763_86-167.png', '/content/data_30/train/3424_108-984.png', '/content/data_30/train/4654_81-39.png', '/content/data_30/train/3872_64-904.png', '/content/data_30/train/2825_109-243.png', '/content/data_30/train/2467_103-944.png', '/content/data_30/train/2390_105-249.png', '/content/data_30/train/3288_165.png', '/content/data_30/train/4573_82-838.png', '/content/data_30/train/754_80-66.png', '/content/data_30/train/3089_152-346.png', '/content/data_30/train/512_91-039.png', '/content/data_30/train/3116_155-588.png', '/content/data_30/train/2647_115-975.png', '/content/data_30/train/2898_106-731.png', '/content/data_30/train/3480_99-341.png', '/content/data_30/train/3390_118-923.png', '/content/data_30/train/4455_80-709.png', '/content/data_30/train/3592_91-967.png', '/content/data_30/train/3796_67-467.png', '/content/data_30/train/4516_83-401.png', '/content/data_30/train/1956_102-891.png', '/content/data_30/train/3651_89-061.png', '/content/data_30/train/557_89-534.png', '/content/data_30/train/519_90-588.png', '/content/data_30/train/1465_50-937.png', '/content/data_30/train/633_73-75.png', '/content/data_30/train/3264_165.png', '/content/data_30/train/647_70-543.png', '/content/data_30/train/3902_64-561.png', '/content/data_30/train/3314_165.png', '/content/data_30/train/3673_86-263.png', '/content/data_30/train/3918_64-618.png', '/content/data_30/train/1271_35-007.png', '/content/data_30/train/1349_37-23.png', '/content/data_30/train/4333_70-419.png', '/content/data_30/train/3245_165.png', '/content/data_30/train/3779_68-758.png', '/content/data_30/train/4055_50-704.png', '/content/data_30/train/155_123-369.png', '/content/data_30/train/3599_91-373.png', '/content/data_30/train/1631_62-277.png', '/content/data_30/train/2063_161-771.png', '/content/data_30/train/2737_110-526.png', '/content/data_30/train/4235_53-789.png', '/content/data_30/train/3203_164-2.png', '/content/data_30/train/1426_46-298.png', '/content/data_30/train/1160_55-07.png', '/content/data_30/train/94_127-1.png', '/content/data_30/train/2177_116-612.png', '/content/data_30/train/579_87-344.png', '/content/data_30/train/3122_155-987.png', '/content/data_30/train/2959_100-588.png', '/content/data_30/train/1302_34-594.png', '/content/data_30/train/1561_60-672.png', '/content/data_30/train/3324_162-353.png', '/content/data_30/train/2665_115-525.png', '/content/data_30/train/2276_108-795.png', '/content/data_30/train/3181_159-538.png', '/content/data_30/train/3101_154-115.png', '/content/data_30/train/2287_108-409.png', '/content/data_30/train/4997_139-233.png', '/content/data_30/train/22_155-785.png', '/content/data_30/tra ...
# ['/content/data_30/train/0_165.png', '/content/data_30/train/1_165.png', '/content/data_30/train/2_165.png', '/content/data_30/train/3_164-899.png', '/content/data_30/train/4_164-566.png', '/content/data_30/train/5_164-208.png', '/content/data_30/train/6_163-82.png', '/content/data_30/train/7_163-416.png', '/content/data_30/train/8_162-996.png', '/content/data_30/train/9_162-545.png', '/content/data_30/train/10_162-083.png', '/content/data_30/train/11_161-608.png', '/content/data_30/train/12_161-123.png', '/content/data_30/train/13_160-628.png', '/content/data_30/train/14_160-123.png', '/content/data_30/train/15_159-603.png', '/content/data_30/train/16_159-075.png', '/content/data_30/train/17_158-538.png', '/content/data_30/train/18_157-994.png', '/content/data_30/train/19_157-442.png', '/content/data_30/train/20_156-885.png', '/content/data_30/train/21_156-321.png', '/content/data_30/train/22_155-785.png', '/content/data_30/train/23_155-244.png', '/content/data_30/train/24_154-7.png', '/content/data_30/train/25_154-153.png', '/content/data_30/train/26_153-598.png', '/content/data_30/train/27_153-041.png', '/content/data_30/train/28_152-481.png', '/content/data_30/train/29_151-92.png', '/content/data_30/train/30_151-357.png', '/content/data_30/train/31_150-793.png', '/content/data_30/train/32_150-229.png', '/content/data_30/train/33_149-664.png', '/content/data_30/train/34_149-151.png', '/content/data_30/train/35_148-638.png', '/content/data_30/train/36_148-126.png', '/content/data_30/train/37_147-613.png', '/content/data_30/train/38_147-101.png', '/content/data_30/train/39_146-586.png', '/content/data_30/train/40_146-072.png', '/content/data_30/train/41_145-559.png', '/content/data_30/train/42_145-047.png', '/content/data_30/train/43_144-537.png', '/content/data_30/train/44_144-029.png', '/content/data_30/train/45_143-522.png', '/content/data_30/train/46_143-017.png', '/content/data_30/train/47_142-562.png', '/content/data_30/train/48_142-117.png', '/content/data_30/train/49_141-673.png', '/content/data_30/train/50_141-23.png', '/content/data_30/train/51_140-788.png', '/content/data_30/train/52_140-349.png', '/content/data_30/train/53_139-908.png', '/content/data_30/train/54_139-469.png', '/content/data_30/train/55_139-033.png', '/content/data_30/train/56_138-598.png', '/content/data_30/train/57_138-166.png', '/content/data_30/train/58_137-736.png', '/content/data_30/train/59_137-308.png', '/content/data_30/train/60_136-883.png', '/content/data_30/train/61_136-511.png', '/content/data_30/train/62_136-141.png', '/content/data_30/train/63_135-77.png', '/content/data_30/train/64_135-401.png', '/content/data_30/train/65_135-033.png', '/content/data_30/train/66_134-668.png', '/content/data_30/train/67_134-301.png', '/content/data_30/train/68_133-937.png', '/content/data_30/train/69_133-575.png', '/content/data_30/train/70_133-21.png', '/content/data_30/train/71_132-846.png', '/content/data_30/train/72_132-485.png', '/content/data_30/train/73_132-126.png', '/content/data_30/train/74_131-772.png', '/content/data_30/train/75_131-46.png', '/content/data_30/train/76_131-15.png', '/content/data_30/train/77_130-837.png', '/content/data_30/train/78_130-526.png', '/content/data_30/train/79_130-217.png', '/content/data_30/train/80_129-909.png', '/content/data_30/train/81_129-601.png', '/content/data_30/train/82_129-295.png', '/content/data_30/train/83_128-99.png', '/content/data_30/train/84_128-687.png', '/content/data_30/train/85_128-386.png', '/content/data_30/train/86_128-086.png', '/content/data_30/train/87_127-787.png', '/content/data_30/train/88_127-49.png', '/content/data_30/train/89_127-227.png', '/content/data_30/train/90_127-22.png', '/content/data_30/train/91_127-223.png', '/content/data_30/train/92_127-189.png', '/content/data_30/train/93_127-144.png', '/content/data_30/train/94_127-1.png', '/content/data_30/train/95_127-054.png', '/content/data_30/train/96_127-006.png', '/content/data_30/train/97_126-954.png', '/content/data_30 ...
# [165.0, 165.0, 165.0, 164.899, 164.566, 164.208, 163.82, 163.416, 162.996, 162.545, 162.083, 161.608, 161.123, 160.628, 160.123, 159.603, 159.075, 158.538, 157.994, 157.442, 156.885, 156.321, 155.785, 155.244, 154.7, 154.153, 153.598, 153.041, 152.481, 151.92, 151.357, 150.793, 150.229, 149.664, 149.151, 148.638, 148.126, 147.613, 147.101, 146.586, 146.072, 145.559, 145.047, 144.537, 144.029, 143.522, 143.017, 142.562, 142.117, 141.673, 141.23, 140.788, 140.349, 139.908, 139.469, 139.033, 138.598, 138.166, 137.736, 137.308, 136.883, 136.511, 136.141, 135.77, 135.401, 135.033, 134.668, 134.301, 133.937, 133.575, 133.21, 132.846, 132.485, 132.126, 131.772, 131.46, 131.15, 130.837, 130.526, 130.217, 129.909, 129.601, 129.295, 128.99, 128.687, 128.386, 128.086, 127.787, 127.49, 127.227, 127.22, 127.223, 127.189, 127.144, 127.1, 127.054, 127.006, 126.954, 126.899, 126.841, 126.78, 126.717, 126.65, 126.581, 126.542, 126.503, 126.456, 126.407, 126.356, 126.303, 126.249, 126.183, 126.114, 126.045, 125.974, 125.902, 125.828, 125.753, 125.676, 125.626, 125.577, 125.522, 125.463, 125.405, 125.346, 125.286, 125.226, 125.165, 125.101, 125.031, 124.953, 124.875, 124.798, 124.721, 124.669, 124.618, 124.562, 124.504, 124.447, 124.39, 124.334, 124.277, 124.221, 124.164, 124.106, 124.049, 123.996, 123.925, 123.849, 123.776, 123.707, 123.639, 123.57, 123.502, 123.435, 123.369, 123.303, 123.239, 123.175, 123.111, 123.048, 122.986, 122.925, 122.87, 122.795, 122.713, 122.636, 122.564, 122.494, 122.329, 122.253, 122.224, 122.188, 122.136, 122.082, 122.032, 121.985, 121.939, 121.894, 121.849, 121.806, 121.674, 121.613, 121.588, 121.558, 121.517, 121.472, 121.431, 121.392, 121.355, 121.319, 121.283, 121.248, 121.214, 121.182, 121.15, 121.12, 121.091, 121.062, 121.035, 121.009, 120.966, 120.922, 120.884, 120.849, 120.815, 120.785, 120.741, 120.688, 120.637, 120.589, 120.545, 120.502, 120.461, 120.327, 120.26, 120.244, 120.237, 120.219, 120.194, 120.169, 120.145, 120.124, 120.104, 120.084, 120.065, 120.046, 120.013, 119.979, 119.949, 119.922, 119.897, 119.871, 119.845, 119.82, 119.806, 119.778, 119.74, 119.699, 119.661, 119.625, 119.591, 119.558, 119.526, 119.494, 119.463, 119.433, 119.404, 119.376, 119.349, 119.323, 119.298, 119.274, 119.25, 119.228, 119.207, 119.187, 119.167, 119.128, 119.088, 119.053, 119.022, 118.993, 118.965, 118.937, 118.91, 118.898, 118.872, 118.832, 118.787, 118.743, 118.702, 118.663, 118.625, 118.589, 118.554, 118.52, 118.488, 118.457, 118.427, 118.398, 118.371, 118.344, 118.316, 118.287, 118.258, 118.23, 118.201, 118.158, 118.115, 118.078, 118.044, 118.013, 117.982, 117.978, 117.958, 117.918, 117.866, 117.809, 117.752, 117.696, 117.64, 117.584, 117.529, 117.474, 117.418, 117.363, 117.307, 117.251, 117.196, 117.14, 117.085, 117.029, 116.973, 116.918, 116.862, 116.806, 116.751, 116.695, 116.639, 116.623, 116.59, 116.532, 116.457, 116.373, 116.285, 116.194, 116.104, 116.014, 115.924, 115.834, 115.744, 115.655, 115.565, 115.476, 115.386, 115.297, 115.208, 115.119, 115.03, 114.941, 114.852, 114.763, 114.674, 114.585, 114.552, 114.503, 114.43, 114.339, 114.234, 114.121, 114.003, 113.882, 113.76, 113.636, 113.512, 113.387, 113.263, 113.138, 113.014, 112.89, 112.767, 112.644, 112.521, 112.399, 112.277, 112.156, 112.034, 111.913, 111.792, 111.728, 111.651, 111.555, 111.442, 111.317, 111.183, 111.043, 110.898, 110.751, 110.602, 110.452, 110.301, 110.149, 109.998, 109.847, 109.697, 109.547, 109.396, 109.246, 109.098, 108.95, 108.803, 108.657, 108.511, 108.419, 108.318, 108.2, 108.068, 107.925, 107.773, 107.616, 107.455, 107.29, 107.124, 106.957, 106.789, 106.621, 106.453, 106.286, 106.119, 105.953, 105.787, 105.622, 105.458, 105.295, 105.132, 104.97, 104.81, 104.693, 104.568, 104.431, 104.282, 104.126, 103.963, 103.796, 103.626, 103.455, 103.282, 103.109, 102.937, 102.765, 102.593, 102.422, 102.238, 102.055, 101.876, 101.701, 101.529, 101.359, 101.192, 101.026, 100.862, 100.704, 100.54, 100.371, 100.197, 100.021, 99.844, 99.666, 99.489,  ...
# ['/content/data_30/test/5253_111-031.png', '/content/data_30/test/5532_89-994.png', '/content/data_30/test/5452_90-397.png', '/content/data_30/test/5459_90-296.png', '/content/data_30/test/5789_98-653.png', '/content/data_30/test/5615_90-017.png', '/content/data_30/test/5233_114-598.png', '/content/data_30/test/5009_136-154.png', '/content/data_30/test/5220_116-491.png', '/content/data_30/test/5397_91-984.png', '/content/data_30/test/5153_120-105.png', '/content/data_30/test/5171_120-122.png', '/content/data_30/test/5790_98-696.png', '/content/data_30/test/5016_134-489.png', '/content/data_30/test/5759_97-119.png', '/content/data_30/test/5990_99-322.png', '/content/data_30/test/5716_94-136.png', '/content/data_30/test/5495_90-031.png', '/content/data_30/test/5849_100-171.png', '/content/data_30/test/5788_98-611.png', '/content/data_30/test/5217_116-944.png', '/content/data_30/test/5760_97-175.png', '/content/data_30/test/5546_89-984.png', '/content/data_30/test/5226_115-592.png', '/content/data_30/test/5988_99-357.png', '/content/data_30/test/5370_93-371.png', '/content/data_30/test/5036_130-136.png', '/content/data_30/test/5160_120-064.png', '/content/data_30/test/5385_92-549.png', '/content/data_30/test/5161_120-054.png', '/content/data_30/test/5943_99-988.png', '/content/data_30/test/5086_122-003.png', '/content/data_30/test/5614_90-015.png', '/content/data_30/test/5318_98-33.png', '/content/data_30/test/5994_99-248.png', '/content/data_30/test/5984_99-428.png', '/content/data_30/test/5607_90-003.png', '/content/data_30/test/5890_100-39.png', '/content/data_30/test/5945_99-96.png', '/content/data_30/test/5835_99-989.png', '/content/data_30/test/5453_90-381.png', '/content/data_30/test/5966_99-702.png', '/content/data_30/test/5225_115-741.png', '/content/data_30/test/5172_120-138.png', '/content/data_30/test/5658_90-7.png', '/content/data_30/test/5523_89-999.png', '/content/data_30/test/5076_123-447.png', '/content/data_30/test/5147_120-05.png', '/content/data_30/test/5558_89-979.png', '/content/data_30/test/5719_94-35.png', '/content/data_30/test/5727_94-965.png', '/content/data_30/test/5272_107-476.png', '/content/data_30/test/5444_90-537.png', '/content/data_30/test/5202_118-585.png', '/content/data_30/test/5623_90-057.png', '/content/data_30/test/5117_120-098.png', '/content/data_30/test/5271_107-662.png', '/content/data_30/test/5138_120-107.png', '/content/data_30/test/5060_125-852.png', '/content/data_30/test/5669_91-155.png', '/content/data_30/test/5213_117-521.png', '/content/data_30/test/5836_100-007.png', '/content/data_30/test/5300_101-546.png', '/content/data_30/test/5591_89-995.png', '/content/data_30/test/5675_91-433.png', '/content/data_30/test/5401_91-813.png', '/content/data_30/test/5549_89-981.png', '/content/data_30/test/5234_114-418.png', '/content/data_30/test/5122_120-092.png', '/content/data_30/test/5244_112-623.png', '/content/data_30/test/5212_117-632.png', '/content/data_30/test/5179_120-048.png', '/content/data_30/test/5441_90-595.png', '/content/data_30/test/5071_124-176.png', '/content/data_30/test/5187_119-665.png', '/content/data_30/test/5347_94-958.png', '/content/data_30/test/5979_99-513.png', '/content/data_30/test/5773_97-927.png', '/content/data_30/test/5079_123-02.png', '/content/data_30/test/5690_92-311.png', '/content/data_30/test/5763_97-35.png', '/content/data_30/test/5181_119-953.png', '/content/data_30/test/5518_90.png', '/content/data_30/test/5681_91-753.png', '/content/data_30/test/5645_90-355.png', '/content/data_30/test/5551_89-979.png', '/content/data_30/test/5842_100-095.png', '/content/data_30/test/5612_90-011.png', '/content/data_30/test/5537_89-991.png', '/content/data_30/test/5460_90-284.png', '/content/data_30/test/5634_90-16.png', '/content/data_30/test/5445_90-518.png', '/content/data_30/test/5159_120-08.png', '/content/data_30/test/5240_113-336.png', '/content/data_30/test/5048_127-994.png', '/content/data_30/test/5618_90-027.png', '/content/data_30/test/5513_90-001.pn ...
# ['/content/data_30/test/5000_138-451.png', '/content/data_30/test/5001_138-192.png', '/content/data_30/test/5002_137-933.png', '/content/data_30/test/5003_137-676.png', '/content/data_30/test/5004_137-42.png', '/content/data_30/test/5005_137-165.png', '/content/data_30/test/5006_136-911.png', '/content/data_30/test/5007_136-658.png', '/content/data_30/test/5008_136-405.png', '/content/data_30/test/5009_136-154.png', '/content/data_30/test/5010_135-904.png', '/content/data_30/test/5011_135-649.png', '/content/data_30/test/5012_135-396.png', '/content/data_30/test/5013_135-162.png', '/content/data_30/test/5014_134-941.png', '/content/data_30/test/5015_134-718.png', '/content/data_30/test/5016_134-489.png', '/content/data_30/test/5017_134-261.png', '/content/data_30/test/5018_134-035.png', '/content/data_30/test/5019_133-81.png', '/content/data_30/test/5020_133-585.png', '/content/data_30/test/5021_133-362.png', '/content/data_30/test/5022_133-14.png', '/content/data_30/test/5023_132-919.png', '/content/data_30/test/5024_132-699.png', '/content/data_30/test/5025_132-48.png', '/content/data_30/test/5026_132-262.png', '/content/data_30/test/5027_132-046.png', '/content/data_30/test/5028_131-826.png', '/content/data_30/test/5029_131-609.png', '/content/data_30/test/5030_131-393.png', '/content/data_30/test/5031_131-178.png', '/content/data_30/test/5032_130-965.png', '/content/data_30/test/5033_130-752.png', '/content/data_30/test/5034_130-541.png', '/content/data_30/test/5035_130-33.png', '/content/data_30/test/5036_130-136.png', '/content/data_30/test/5037_129-954.png', '/content/data_30/test/5038_129-772.png', '/content/data_30/test/5039_129-59.png', '/content/data_30/test/5040_129-409.png', '/content/data_30/test/5041_129-229.png', '/content/data_30/test/5042_129-049.png', '/content/data_30/test/5043_128-871.png', '/content/data_30/test/5044_128-694.png', '/content/data_30/test/5045_128-517.png', '/content/data_30/test/5046_128-342.png', '/content/data_30/test/5047_128-167.png', '/content/data_30/test/5048_127-994.png', '/content/data_30/test/5049_127-818.png', '/content/data_30/test/5050_127-645.png', '/content/data_30/test/5051_127-473.png', '/content/data_30/test/5052_127-29.png', '/content/data_30/test/5053_127-105.png', '/content/data_30/test/5054_126-923.png', '/content/data_30/test/5055_126-742.png', '/content/data_30/test/5056_126-562.png', '/content/data_30/test/5057_126-382.png', '/content/data_30/test/5058_126-204.png', '/content/data_30/test/5059_126-027.png', '/content/data_30/test/5060_125-852.png', '/content/data_30/test/5061_125-697.png', '/content/data_30/test/5062_125-543.png', '/content/data_30/test/5063_125-388.png', '/content/data_30/test/5064_125-233.png', '/content/data_30/test/5065_125-08.png', '/content/data_30/test/5066_124-927.png', '/content/data_30/test/5067_124-775.png', '/content/data_30/test/5068_124-625.png', '/content/data_30/test/5069_124-475.png', '/content/data_30/test/5070_124-326.png', '/content/data_30/test/5071_124-176.png', '/content/data_30/test/5072_124-028.png', '/content/data_30/test/5073_123-882.png', '/content/data_30/test/5074_123-736.png', '/content/data_30/test/5075_123-591.png', '/content/data_30/test/5076_123-447.png', '/content/data_30/test/5077_123-304.png', '/content/data_30/test/5078_123-161.png', '/content/data_30/test/5079_123-02.png', '/content/data_30/test/5080_122-879.png', '/content/data_30/test/5081_122-738.png', '/content/data_30/test/5082_122-599.png', '/content/data_30/test/5083_122-46.png', '/content/data_30/test/5084_122-311.png', '/content/data_30/test/5085_122-153.png', '/content/data_30/test/5086_122-003.png', '/content/data_30/test/5087_121-864.png', '/content/data_30/test/5088_121-725.png', '/content/data_30/test/5089_121-585.png', '/content/data_30/test/5090_121-446.png', '/content/data_30/test/5091_121-309.png', '/content/data_30/test/5092_121-172.png', '/content/data_30/test/5093_121-036.png', '/content/data_30/test/5094_120-901.png', '/content/data_30/t ...
# [138.451, 138.192, 137.933, 137.676, 137.42, 137.165, 136.911, 136.658, 136.405, 136.154, 135.904, 135.649, 135.396, 135.162, 134.941, 134.718, 134.489, 134.261, 134.035, 133.81, 133.585, 133.362, 133.14, 132.919, 132.699, 132.48, 132.262, 132.046, 131.826, 131.609, 131.393, 131.178, 130.965, 130.752, 130.541, 130.33, 130.136, 129.954, 129.772, 129.59, 129.409, 129.229, 129.049, 128.871, 128.694, 128.517, 128.342, 128.167, 127.994, 127.818, 127.645, 127.473, 127.29, 127.105, 126.923, 126.742, 126.562, 126.382, 126.204, 126.027, 125.852, 125.697, 125.543, 125.388, 125.233, 125.08, 124.927, 124.775, 124.625, 124.475, 124.326, 124.176, 124.028, 123.882, 123.736, 123.591, 123.447, 123.304, 123.161, 123.02, 122.879, 122.738, 122.599, 122.46, 122.311, 122.153, 122.003, 121.864, 121.725, 121.585, 121.446, 121.309, 121.172, 121.036, 120.901, 120.767, 120.633, 120.501, 120.371, 120.241, 120.112, 119.983, 120.012, 120.053, 120.065, 120.07, 120.081, 120.094, 120.106, 120.118, 120.13, 120.147, 120.132, 120.117, 120.111, 120.107, 120.102, 120.098, 120.094, 120.092, 120.091, 120.091, 120.092, 120.094, 120.096, 120.099, 120.104, 120.109, 120.116, 120.123, 120.132, 120.142, 120.153, 120.166, 120.187, 120.177, 120.148, 120.123, 120.107, 120.095, 120.083, 120.072, 120.063, 120.056, 120.051, 120.049, 120.048, 120.05, 120.054, 120.06, 120.068, 120.079, 120.091, 120.105, 120.122, 120.16, 120.166, 120.139, 120.105, 120.08, 120.064, 120.054, 120.046, 120.04, 120.038, 120.04, 120.045, 120.055, 120.068, 120.085, 120.105, 120.122, 120.138, 120.154, 120.224, 120.243, 120.211, 120.156, 120.1, 120.048, 120.0, 119.953, 119.906, 119.858, 119.81, 119.762, 119.714, 119.665, 119.617, 119.569, 119.52, 119.472, 119.423, 119.424, 119.39, 119.318, 119.222, 119.116, 119.009, 118.901, 118.795, 118.69, 118.585, 118.48, 118.375, 118.27, 118.165, 118.06, 117.955, 117.85, 117.766, 117.713, 117.632, 117.521, 117.388, 117.244, 117.095, 116.944, 116.793, 116.642, 116.491, 116.341, 116.19, 116.04, 115.891, 115.741, 115.592, 115.444, 115.35, 115.239, 115.101, 114.944, 114.774, 114.598, 114.418, 114.238, 114.056, 113.876, 113.695, 113.515, 113.336, 113.157, 112.978, 112.801, 112.623, 112.447, 112.301, 112.145, 111.975, 111.794, 111.606, 111.416, 111.223, 111.031, 110.839, 110.648, 110.457, 110.267, 110.078, 109.889, 109.702, 109.515, 109.328, 109.154, 108.977, 108.793, 108.606, 108.417, 108.227, 108.038, 107.849, 107.662, 107.476, 107.291, 107.066, 106.84, 106.624, 106.417, 106.215, 106.016, 105.82, 105.578, 105.338, 105.109, 104.89, 104.676, 104.466, 104.258, 104.05, 103.844, 103.64, 103.436, 103.234, 103.014, 102.795, 102.582, 102.374, 102.168, 101.964, 101.75, 101.546, 101.354, 101.168, 100.984, 100.802, 100.621, 100.44, 100.261, 100.084, 99.907, 99.724, 99.544, 99.367, 99.194, 99.022, 98.852, 98.683, 98.496, 98.33, 98.181, 98.039, 97.897, 97.756, 97.615, 97.476, 97.34, 97.205, 97.072, 96.939, 96.808, 96.678, 96.547, 96.417, 96.288, 96.162, 96.027, 95.901, 95.804, 95.719, 95.636, 95.547, 95.46, 95.375, 95.29, 95.206, 95.123, 95.04, 94.958, 94.876, 94.795, 94.715, 94.635, 94.556, 94.475, 94.396, 94.319, 94.238, 94.169, 94.105, 94.042, 93.979, 93.916, 93.854, 93.792, 93.73, 93.669, 93.609, 93.549, 93.489, 93.43, 93.371, 93.313, 93.256, 93.197, 93.14, 93.084, 93.028, 92.973, 92.918, 92.864, 92.81, 92.757, 92.704, 92.652, 92.6, 92.549, 92.499, 92.449, 92.4, 92.351, 92.304, 92.257, 92.21, 92.164, 92.118, 92.073, 92.028, 91.984, 91.94, 91.897, 91.855, 91.813, 91.771, 91.73, 91.69, 91.65, 91.61, 91.571, 91.533, 91.495, 91.458, 91.421, 91.386, 91.352, 91.318, 91.285, 91.252, 91.22, 91.188, 91.156, 91.126, 91.095, 91.066, 91.036, 91.008, 90.979, 90.951, 90.924, 90.897, 90.87, 90.844, 90.818, 90.793, 90.768, 90.744, 90.722, 90.7, 90.678, 90.657, 90.636, 90.615, 90.595, 90.575, 90.556, 90.537, 90.518, 90.5, 90.482, 90.464, 90.447, 90.43, 90.413, 90.397, 90.381, 90.366, 90.351, 90.336, 90.321, 90.308, 90.296, 90.284, 90.273, 90.261, 90.25, 90.239, 90.228, 90.218, 90.208, 90.198, 90.18 ...

# %% [markdown]
# ## Part 4: Loading in the images
#
# The below code is outside the scope of this course but a brief explanation is provided nevertheless.
#
# ### Dataset Creation
# The dataset creation involves the creation of what is known as a dataset pipeline. All this is, is a sequence of transformations applied one after the other that manipulate the data in different ways.
# 1. from_tensor_slices. We load in the images and the steering angles into the dataset
# 2. repeat. Simply loop the dataset for infinity when we get to the end. This is done to make sure our network never runs out of data. For instance we train on batches of 32 if we had 52 images we would run out of data.
# 3. shuffle. Self explanatory makes sure we don't feed network ordered data as this can cause weird issues. Note we don't need to do this with our validation data so we might as well save the unnecessary operation by excluding shuffle.
# 4. batch. Tell the dataset that when we fetch a item from it is should return a number of items. This is more efficient as you almost certainly have enough RAM to handle more than 1 image.
# 5. Prefetch. Tell the dataset that when it's not doing anything it should automatically be loading data into RAM in the background. This results in huge performance increases as when we're training we don't have to sit around waiting for the dataset to load the images.

# %%
import matplotlib.pyplot as plt # import matplotlib for plotting
import tensorflow as tf
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
import tqdm

train_data = []
test_data = []

tqdm.tqdm.write("Loading training data")
# load the images and steering angles into numpy arrays
for path in tqdm.tqdm(train_img):
    img = cv.imread(path) # read the image
    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    # mask the image to get only the desired colors
    mask = cv.inRange(hsv, (36, 0, 0), (70, 255,255))
    array = np.array(mask, dtype=np.float32)
    train_data.append(array)

tqdm.tqdm.write("Loading test data")
# loading the testing data
for path in tqdm.tqdm(test_img):
    img = cv.imread(path) # read the image
    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    # mask the image to get only the desired colors
    mask = cv.inRange(hsv, (36, 0, 0), (70, 255,255))
    array = np.array(mask, dtype=np.float32)
    test_data.append(array)

# create a dataset from the training data and make a data pipeline
train_ds = tf.data.Dataset.from_tensor_slices((train_data, train_steer)) # create a dataset from the image paths and steering angles
train_ds = train_ds.repeat()
train_ds = train_ds.shuffle(buffer_size=len(train_img)) # shuffle the dataset
train_ds = train_ds.batch(BATCH_SIZE) # batch the dataset
train_ds = train_ds.prefetch(tf.data.experimental.AUTOTUNE) # prefetch the dataset to improve performance

# create a dataset from the testing data and make a data pipeline
test_ds = tf.data.Dataset.from_tensor_slices((test_data, test_steer)) # create a dataset from the image paths and steering angles
test_ds = test_ds.repeat() # repeat the dataset
test_ds = test_ds.batch(BATCH_SIZE) # batch the dataset
test_ds = test_ds.prefetch(tf.data.experimental.AUTOTUNE) # prefetch the dataset to improve performance

# output the first 16 images and steering angles from the dataset
fig, axs = plt.subplots(4, 4, figsize=(8, 8))
# add title to the figure
fig.suptitle('Training Data')
fig.tight_layout()

imgs, steer = next(iter(train_ds)) # get the first batch of images and steering angles

for i in range(16):
    axs[i//4, i%4].axis('off')
    axs[i//4, i%4].imshow(imgs[i])
    axs[i//4, i%4].set_title(round(steer[i].numpy(), 2))
plt.tight_layout()
plt.show()
# Out:
# Loading training data
# 100%|██████████| 5000/5000 [00:03<00:00, 1456.67it/s]
# Loading test data
# 100%|██████████| 1000/1000 [00:00<00:00, 2800.99it/s]

# %% [markdown]
# ## Part 5: This is where you will create your model
# try modifying the layers to try to get the lowest mse score,
# This is going to require some trial and error so make sure you spend some time experimenting.

# %%
import numpy as np
np.random.seed(1337)  # for reproducibility
import keras as ks
from keras.models import Sequential
from keras.layers import Dense, InputLayer, Conv2D, Flatten, MaxPool2D, Dropout
from keras.optimizers import Adam
import matplotlib.pyplot as plt

# a sequential model is a model that is made up of layers
model = Sequential()
# the input layer is the first layer in the model. You shouldn't need to change this.
model.add(InputLayer(input_shape=(66, 100, 1), batch_size=BATCH_SIZE))

# try modifying the number of nodes in the hidden layer to see how it affects the model
# you can also try changing the activation function to see how it affects the model
# adding more layers to the model may also help you to acheive your score

# in this lab you also have access to the Conv2D layer and MaxPool2D layer. Try modifying these to see how they affect the model.
model.add(Conv2D(32, (3, 3), activation='relu'))  # conv layer 32 filters size 3x3
model.add(MaxPool2D(pool_size=(2, 2)))  # pooling layer size 3x3
model.add(Conv2D(64, (3, 3), activation='relu'))  # conv filters size 3x3
model.add(MaxPool2D(pool_size=(2, 2)))  # pooling layer size
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))


model.add(Flatten())  # flatten layer
model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))


optimizer = Adam(learning_rate=0.001)  # try changing the learning rate to see how it affects the model
model.compile(optimizer=optimizer, loss='mse')  # we will keep track of the mean squared error

print(model.summary())  # print a summary of the model

# Train the model without EarlyStopping
epoch = 15
hist = model.fit(train_ds,
                 steps_per_epoch=len(train_img) // BATCH_SIZE,
                 validation_data=test_ds,
                 validation_steps=len(test_img) // BATCH_SIZE,
                 epochs=epoch)  # EarlyStopping removed

# let's plot the model's history
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
# plt.plot(np.log(hist.history['loss']))       # log scale
# plt.plot(np.log(hist.history['val_loss']))   # log scale
plt.title('model mean squared error loss')
plt.ylabel('mean squared error loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (32, 64, 98, 32)       │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (32, 32, 49, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (32, 30, 47, 64)       │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (32, 15, 23, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (32, 13, 21, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (32, 6, 10, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (32, 7680)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 128)              │       983,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32, 64)               │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (32, 32)               │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (32, 1)                │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,086,209 (4.14 MB)
#  Trainable params: 1,086,209 (4.14 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 2572.7178 - val_loss: 107.3780
# Epoch 2/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 44.6776 - val_loss: 49.9320
# Epoch 3/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 33.1697 - val_loss: 74.5891
# Epoch 4/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 43.2787 - val_loss: 64.6859
# Epoch 5/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 42.5894 - val_loss: 110.0825
# Epoch 6/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 38.8075 - val_loss: 62.1769
# Epoch 7/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 36.0283 - val_loss: 95.1703
# Epoch 8/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 37.0071 - val_loss: 60.4227
# Epoch 9/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 35.2788 - val_loss: 71.7167
# Epoch 10/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 34.6597 - val_loss: 63.1790
# Epoch 11/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 34.7170 - val_loss: 108.1355
# Epoch 12/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 42.6698 - val_loss: 56.2595
# Epoch 13/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 37.5825 - val_loss: 52.7641
# Epoch 14/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 42.6533 - val_loss: 56.7717
# Epoch 15/15
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 38.0928 - val_loss: 59.5406

# %% [markdown]
# ### Optimization Strategies for Neural Networks
#
# Here are some common ways to optimize your neural network model and potentially achieve a lower Mean Squared Error (MSE):
#
# 1.  **Model Architecture**: Experiment with adding or removing layers (`Dense`, `Conv2D`, `MaxPool2D`), changing the number of filters in convolutional layers, or the number of neurons in dense layers. Deeper or wider networks can learn more complex patterns but also risk overfitting.
#
# 2.  **Activation Functions**: While `relu` is generally effective for hidden layers, you could explore others like `LeakyReLU`, `ELU`, or `tanh`. The output layer's activation function (`linear` for regression) should typically remain the same.
#
# 3.  **Regularization**: Techniques to prevent overfitting:
#     *   **Dropout**: Randomly sets a fraction of input units to 0 at each update during training time, which helps prevent co-adaptation of neurons. A dropout rate of 0.1-0.5 is common.
#     *   **L1/L2 Regularization**: Adds a penalty to the loss function based on the magnitude of the weights, encouraging simpler models.
#
# 4.  **Optimizer and Learning Rate**: The `Adam` optimizer is a good default, but you could try `RMSprop` or `SGD` (Stochastic Gradient Descent) with momentum. The `learning_rate` is crucial; too high can cause the model to overshoot, too low can make training very slow. Experiment with values like 0.01, 0.001, 0.0001.
#
# 5.  **Early Stopping**: Monitor a metric (like validation loss) and stop training when it stops improving. This prevents overfitting and saves computation time.
#
# 6.  **Batch Size**: The `BATCH_SIZE` can impact training stability and speed. Smaller batch sizes might lead to more noisy updates but can help with generalization, while larger ones provide more stable gradient estimates.
#
# 7.  **Data Augmentation**: (More advanced for this setup) Randomly transform your training images (e.g., small rotations, shifts, brightness changes) to create more diverse training data. This makes the model more robust.

# %%
# import numpy as np
# np.random.seed(1337)  # for reproducibility
# import keras as ks
# from keras.models import Sequential
# from keras.layers import Dense, InputLayer, Conv2D, Flatten, MaxPool2D, Dropout
# from keras.optimizers import Adam
# from keras.callbacks import EarlyStopping # Import EarlyStopping
# import matplotlib.pyplot as plt

# # a sequential model is a model that is made up of layers
# model = Sequential()
# # the input layer is the first layer in the model. You shouldn't need to change this.
# model.add(InputLayer(input_shape=(66, 100, 1), batch_size=BATCH_SIZE))

# # try modifying the number of nodes in the hidden layer to see how it affects the model
# # you can also try changing the activation function to see how it affects the model
# # adding more layers to the model may also help you to acheive your score

# # in this lab you also have access to the Conv2D layer and MaxPool2D layer. Try modifying these to see how they affect the model.
# model.add(Conv2D(32, (3, 3), activation='relu'))  # conv layer 32 filters size 3x3
# model.add(MaxPool2D(pool_size=(2, 2)))  # pooling layer size 3x3
# model.add(Conv2D(64, (3, 3), activation='relu'))  # conv filters size 3x3
# model.add(MaxPool2D(pool_size=(2, 2)))  # pooling layer size

# model.add(Flatten())  # flatten layer
# model.add(Dense(32, activation='relu'))
# model.add(Dropout(0.2)) # Uncommented and set dropout rate
# model.add(Dense(16, activation='relu'))
# model.add(Dense(1, activation='linear'))


# optimizer = Adam(learning_rate=0.001)  # try changing the learning rate to see how it affects the model
# model.compile(optimizer=optimizer, loss='mse')  # we will keep track of the mean squared error

# print(model.summary())  # print a summary of the model

# # Define EarlyStopping callback
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# # Train the model with EarlyStopping
# epoch = 50 # Increased epochs to allow EarlyStopping to work
# hist = model.fit(train_ds,
#                  steps_per_epoch=len(train_img) // BATCH_SIZE,
#                  validation_data=test_ds,
#                  validation_steps=len(test_img) // BATCH_SIZE,
#                  epochs=epoch,
#                  callbacks=[early_stopping]) # Added EarlyStopping

# # let's plot the model's history
# plt.plot(hist.history['loss'])
# plt.plot(hist.history['val_loss'])
# # plt.plot(np.log(hist.history['loss']))       # log scale
# # plt.plot(np.log(hist.history['val_loss']))   # log scale
# plt.title('model mean squared error loss')
# plt.ylabel('mean squared error loss')
# plt.xlabel('epoch')
# plt.legend(['training set', 'validation set'], loc='upper right')
# plt.show()

# %% [markdown]
# Have a look at the graph generated below. With this you can get an idea of whether your model is training well. You should want to see both lines trend downwards.

# %% [markdown]
# ## Part 6: Test the model
# We'll now output 16 images with the predicted steering angles along with the actual steering angles

# %%
# output the first 16 images and steering angles from the test dataset then predict the steering angle for the images
fig, axs = plt.subplots(4, 4, figsize=(8, 8))
# add title to the figure
fig.suptitle('Training Data')
fig.tight_layout()

imgs, steer = next(iter(test_ds)) # get the first batch of images and steering angles

for i in range(16):
    axs[i//4, i%4].axis('off')
    axs[i//4, i%4].imshow(imgs[i])
    axs[i//4, i%4].set_title(round(steer[i].numpy(), 2))
    predicted = model(imgs[i].numpy().reshape(1, 66, 100, 1)) # predict the steering angle for the image
    axs[i//4, i%4].set_title("Predicted: " + str(np.round(predicted[0][0].numpy(), 2)) + "\n Actual: " + str(round(steer[i].numpy(), 2)))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 7: export your model
# Once you are happy with your model you can export it by running the code below.
# This will save your model as model.h5 and model.onnx.
#
# The ".h5" model is used for the physical PiCar and the ".onnx" model is used for the PiCar Simulator. You can change this to be more descriptive. I also recommend saving multiple models with different training settings so you have a couple to experiment with.

# %%
# !pip install onnx
# !pip install tf2onnx
# Out:
# Collecting onnx
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.3)
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 85.7 MB/s eta 0:00:00
# Installing collected packages: onnx
# Successfully installed onnx-1.21.0
# Collecting tf2onnx
#   Downloading tf2onnx-1.17.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (2.0.2)
# Requirement already satisfied: onnx>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (1.21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (2.32.4)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (25.9.23)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tf2onnx) (5.29.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->tf2onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->tf2onnx) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->tf2onnx) (2025.10.5)
# Downloading tf2onnx-1.17.0-py3-none-any.whl (839 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 839.1/839.1 kB 26.0 MB/s eta 0:00:00
# Installing collected packages: tf2onnx
# Successfully installed tf2onnx-1.17.0

# %%
import onnx
import tf2onnx
import tensorflow as tf

model_name = "conv_model" # change the name to something more descriptive if you want
model.save(model_name + '.keras')
model.save(model_name + ".h5")
model.output_names = ['output']
input_signature = [tf.TensorSpec([None, 66, 100, 1], tf.float32, name='input')]

onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature=input_signature, opset=13)

onnx.save(onnx_model, model_name + ".onnx")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
